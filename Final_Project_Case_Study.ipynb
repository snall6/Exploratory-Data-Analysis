# %% [markdown]
# <a href="https://colab.research.google.com/github/snall6/Exploratory-Data-Analysis/blob/main/Final_Project_Case_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# ### 🔨 Import packages and dataset

# %% [markdown]
# ▶️ Run the code cell below to import packages used in the case.

# %%
import pandas as pd
import numpy as np
import plotly
import plotly.express as px
import plotly.graph_objects as go

# plotly.io is a low-level interface for interacting with figures/
# plotly.io.templates lists available plotly templates
# https://plotly.com/python-api-reference/plotly.io.html
import plotly.io as pio

pd.set_option('display.max_columns', 50)

# %% [markdown]
# #### 🧭 Check Plotly Version
#
# Run the code below to ensure that your notebook uses the same Plotly version as the autograder.

# %%
# DO NOT CHANGE THE CODE IN THIS CELL
print(f'The current plotly version is {plotly.__version__}')
# Out:
# The current plotly version is 5.5.0

# %% [markdown]
# ▶️ Run the code below to import and process the trips dataset.

# %%
df = pd.read_csv('https://github.com/snall6/Exploratory-Data-Analysis/raw/main/ds_salaries.csv')

# Create a copy for 🧭 Check Your Work section
df_backup = df.copy()

# %% [markdown]
# #Part 1: Data Description
#
# ##Why I Picked the Dataset
#
# I picked this dataset because I thought the content would be interesting to analyze. Since it's about jobs involving data, which is what this class prepares us for, I thought it would be interesting to learn more about it. I'm also interested in a career involving data, so learning about the options through a fairly recent data set about jobs and their considerations was also cool.
#
# ##Questions to Answer
# A few questions about this dataset that can be answered from analyzing it include:
# 1. What is the highest paying job?
# 2. What country offers the highest paying job?
# 3. Which experience level has the most jobs?
# 4. Is there any correlation between remote requirements vs salary?
# 5. What entry level position pays the most?
#
# ---

# %% [markdown]
# ---
#
# ## 📐 Part 2: Data Overview

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 1: Rows & Columns
#
# #### 👇 Tasks
#
# - ✔️ Display the size of `df` using `.shape`.

# %%
# YOUR CODE BEGINS
num_rows = df.shape[0]
num_cols = df.shape[1]
print("Rows: ", num_rows, " \nCols: ", num_cols)
# YOUR CODE ENDS
# Out:
# Rows:  607
# Cols:  12

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 2: Summary of DataFrame
#
# #### 👇 Tasks
#
# - ✔️ Print a concise summary of `df` using `.info()`.

# %%
# YOUR CODE BEGINS
df.rename(columns={ df.columns[0]: "index" }, inplace = True)
df.info()
# YOUR CODE ENDS
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 3: Browse Through Dataframe
#
# #### 👇 Tasks
#
# - ✔️ Browse through `df` using `.head(n)`, `.tail(n)`, and `.sample(n)`.

# %%
# YOUR CODE BEGINS
df.head(5)
# YOUR CODE ENDS
# Out:
#    index  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %%
# YOUR CODE BEGINS
df.tail(5)
# YOUR CODE ENDS
# Out:
#      index  work_year experience_level employment_type      job_title  salary  \
# 602    602       2022               SE              FT  Data Engineer  154000
# 603    603       2022               SE              FT  Data Engineer  126000
# 604    604       2022               SE              FT   Data Analyst  129000
# 605    605       2022               SE              FT   Data Analyst  150000
# 606    606       2022               MI              FT   AI Scientist  200000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602             USD         154000                 US           100
# 603             USD         126000                 US           100
# 604             USD         129000                 US             0
# 605             USD         150000                 US           100
# 606             USD         200000                 IN           100
#
#     company_location company_size
# 602               US            M
# 603               US            M
# 604               US            M
# 605               US            M
# 606               US            L

# %%
# YOUR CODE BEGINS
df.sample(7)
# YOUR CODE ENDS
# Out:
#      index  work_year experience_level employment_type  \
# 597    597       2022               SE              FT
# 227    227       2021               MI              FT
# 272    272       2021               EN              FT
# 557    557       2022               SE              FT
# 330    330       2022               SE              FT
# 338    338       2022               SE              FT
# 345    345       2022               SE              FT
#
#                    job_title  salary salary_currency  salary_in_usd  \
# 597             Data Analyst  170000             USD         170000
# 227           Data Scientist   75000             EUR          88654
# 272  Data Science Consultant   65000             EUR          76833
# 557            Data Engineer   70500             USD          70500
# 330             Data Analyst  112900             USD         112900
# 338             Data Analyst  136600             USD         136600
# 345            Data Engineer  156600             USD         156600
#
#     employee_residence  remote_ratio company_location company_size
# 597                 US           100               US            M
# 227                 DE            50               DE            L
# 272                 DE             0               DE            L
# 557                 US             0               US            M
# 330                 US           100               US            M
# 338                 US           100               US            M
# 345                 US           100               US            M

# %% [markdown]
# ---
#
# ## 😷 Part 3: Analyze Information

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 4: Total number of data scientists, data analysts, and entry level positions
#
# #### 👇 Tasks
#
# - ✔️Create new dataframes for the three values above and find their sizes

# %%
# YOUR CODE BEGINS
df_data_scientists = df[df['job_title'] == 'Data Scientist']
df_data_analysts = df[df['job_title'] == 'Data Analyst']
df_entry_level = df[df['experience_level'] == 'EN']
num_data_analysts = df_data_analysts.shape[0]
num_data_scientsts = df_data_scientists.shape[0]
num_entry_level = df_entry_level.shape[0]
print("Num Data Scientists: ", num_data_scientsts)
print("Num Data Analyists: ", num_data_analysts)
print("Num Entry Level Jobs: ", num_entry_level)
# YOUR CODE ENDS
# Out:
# Num Data Scientists:  143
# Num Data Analyists:  97
# Num Entry Level Jobs:  88

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 5: Highest Paying Entry Level & Data Scientist Jobs
# #### 👇 Tasks
#
# - ✔️ Using `df`, find the highest paying entry level jobs.

# %%
# YOUR CODE BEGINS
df_entry_level_by_salary = df_entry_level.sort_values(by=["salary_in_usd"], ascending=False,inplace=False)
df_data_scientists_by_remote_ratio_salary = df_data_scientists.sort_values(by=["salary_in_usd", "remote_ratio"], ascending=False,inplace=False)

# YOUR CODE ENDS
display(df_entry_level_by_salary.head(5))
display(df_data_scientists_by_remote_ratio_salary.head(5))
# Out:
#      index  work_year experience_level employment_type  \
# 37      37       2020               EN              FT
# 115    115       2021               EN              FT
# 510    510       2022               EN              FT
# 39      39       2020               EN              FT
# 159    159       2021               EN              FT
#
#                              job_title  salary salary_currency  salary_in_usd  \
# 37           Machine Learning Engineer  250000             USD         250000
# 115         Machine Learning Scientist  225000             USD         225000
# 510  Computer Vision Software Engineer  150000             USD         150000
# 39           Machine Learning Engineer  138000             USD         138000
# 159          Machine Learning Engineer  125000             USD         125000
#
#     employee_residence  remote_ratio company_location company_size
# 37                  US            50               US            L
# 115                 US           100               US            L
# 510                 AU           100               AU            S
# 39                  US           100               US            S
# 159                 US           100               US            S
#      index  work_year experience_level employment_type       job_title  \
# 63      63       2020               SE              FT  Data Scientist
# 416    416       2022               SE              FT  Data Scientist
# 486    486       2022               SE              FT  Data Scientist
# 592    592       2022               SE              FT  Data Scientist
# 472    472       2022               SE              FT  Data Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 63   412000             USD         412000                 US           100
# 416  260000             USD         260000                 US           100
# 486  230000             USD         230000                 US           100
# 592  230000             USD         230000                 US           100
# 472  220000             USD         220000                 US           100
#
#     company_location company_size
# 63                US            L
# 416               US            M
# 486               US            M
# 592               US            M
# 472               US            M

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 6: Average Salary by Position
#
# #### 👇 Tasks
#
# - ✔️ Using `df`, calculate the average salary of all jobs by title and experience level

# %%
# YOUR CODE BEGINS
df_salary = df.groupby(['job_title', 'experience_level'], as_index=False).agg({
    'salary_in_usd':'mean'
}).rename(columns={"salary_in_usd":"avg_salary"})
df_salary.sort_values(by=["avg_salary", "experience_level"], ascending=False, inplace=True)

# YOUR CODE ENDS
display(df_salary.head(10))
display(df_salary.tail(10))
# Out:
#                      job_title experience_level     avg_salary
# 95     Principal Data Engineer               EX  600000.000000
# 61      Financial Data Analyst               MI  450000.000000
# 97    Principal Data Scientist               EX  416000.000000
# 33         Data Analytics Lead               SE  405000.000000
# 8       Applied Data Scientist               SE  278500.000000
# 78                 ML Engineer               SE  256000.000000
# 38               Data Engineer               EX  245500.000000
# 62                Head of Data               EX  232500.000000
# 88  Machine Learning Scientist               EN  225000.000000
# 90  Machine Learning Scientist               SE  201666.666667
#                               job_title experience_level    avg_salary
# 16                    Big Data Engineer               MI  33537.000000
# 63                         Head of Data               MI  32974.000000
# 11                      BI Data Analyst               EN  32136.000000
# 9    Applied Machine Learning Scientist               EN  31875.000000
# 15                    Big Data Engineer               EN  30703.333333
# 1                          AI Scientist               EN  21987.250000
# 30              Data Analytics Engineer               EN  20000.000000
# 76                          ML Engineer               EN  18974.500000
# 100                Product Data Analyst               MI  13036.000000
# 0         3D Computer Vision Researcher               MI   5409.000000

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 7: Average Salary by Location and Experience Level
#
# #### 👇 Tasks
#
# - ✔️ Using `df`, calculate the average salary of jobs by location of employee residence and experience level

# %%
# YOUR CODE BEGINS
df_location_experience = df.groupby(['employee_residence', "experience_level"], as_index=False).agg({
    'salary_in_usd':'mean'
}).rename(columns={"salary_in_usd":"avg_salary"})
df_location_experience.sort_values(by=["avg_salary"], ascending=False, inplace=True)

# YOUR CODE ENDS
display(df_location_experience.head(10))
display(df_location_experience.tail(10))
# Out:
#    employee_residence experience_level     avg_salary
# 97                 US               EX  249991.666667
# 60                 JP               SE  214000.000000
# 67                 MY               SE  200000.000000
# 79                 PR               SE  160000.000000
# 15                 CA               EX  157583.000000
# 86                 RU               EX  157500.000000
# 99                 US               SE  153921.810427
# 55                 IT               EX  153667.000000
# 24                 DE               EX  135936.000000
# 98                 US               MI  135617.792208
#     employee_residence experience_level  avg_salary
# 95                  UA               EN     13400.0
# 12                  BR               MI     12901.0
# 11                  BR               EN     12000.0
# 30                  ES               EN     10354.0
# 76                  PK               MI     10000.0
# 68                  NG               EN     10000.0
# 61                  KE               EN      9272.0
# 53                  IR               MI      4000.0
# 100                 VN               EN      4000.0
# 65                  MX               MI      2859.0

# %% [markdown]
# ---
#
# ## 💵 Part 4: Visualize Data

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 8: USD Salary Box Plot for Entry Level Positions (horizontal)
#
# #### 👇 Tasks
#
# - ✔️ Draw a horizontal box plot of `salary_in_usd` for entry levle positions.
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Add an appropriate title to your figure.
#     - A title should describe your plot (e.g., Salary Box Plot).
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
fig = px.box(x=df_entry_level['salary_in_usd'], orientation='h', title='Horizontal Box Plot of Salary in USD')
fig.show()
# YOUR CODE ENDS
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="377e78b9-1bf5-4b09-9728-090a3a3ed70d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("377e78b9-1bf5-4b09-9728-090a3a3ed70d")) {                    Plotly.newPlot(                        "377e78b9-1bf5-4b09-9728-090a3a3ed70d",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[72000,51321,39916,41689,5707,42000,100000,70000,250000,10000,138000,15966,6072,91000,45896,54742,21669,62726,49268,105000,82528,80000,59102,76833,29751,12000,70000,30428,12000,225000,90000,50000,110037,10354,20000,100000,49646,100000,80000,13400,125000,63831,80000,55000,60000,81000,21844,9272,90000,5882,24823,28609,16228,4000,21637,18053,36643,90000,28399,65013,72500,76833,85000,100000,58000,59102,100000,52351,45807,37300,21983,125000,100000,18442,120000,100000,31875,58035,52396,40000,86703,120000,150000,65000,20000,10000,67000,52000],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6 ...

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 9: Average Salary By Position
#
# #### 👇 Tasks
#
# - ✔️ Draw a histogram (vertical) of `avg_salary` in `df_salary`.
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Add an appropriate title to your figure.
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
fig = px.histogram(df_salary, title='Distribution of average salary by position', x='avg_salary')
fig.show()
# YOUR CODE ENDS
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="acfabdb3-1417-4cf7-b3a3-0919252bde6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("acfabdb3-1417-4cf7-b3a3-0919252bde6a")) {                    Plotly.newPlot(                        "acfabdb3-1417-4cf7-b3a3-0919252bde6a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"avg_salary=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[600000.0,450000.0,416000.0,405000.0,278500.0,256000.0,245500.0,232500.0,225000.0,201666.66666666666,200000.0,199586.33333333334,195000.0,195000.0,192500.0,187939.4,182076.625,178800.0,170000.0,170000.0,168000.0,166666.66666666666,166040.0,165000.0,160000.0,160000.0,159000.0,158958.33333333334,156738.0,155000.0,152971.0163934426,151419.5,151000.0,150000.0,149994.2,137035.84126984127,137025.0,136498.14285714287,131176.0,127134.28571428571,120000.0,118187.0,117104.0,115285.0,115000.0,111922.62962962964,111535.5,110037.0,110000.0,110000.0,110000.0,109325.0,105619.0,105000.0,103000.0,100000.0,100000.0,99703.0,95746.0,93610.5,89294.0,88859.4,88654.0,87932.0,86996.33333333333,86132.0,85985.6603773585,82039.13333333333,79833.0,79551.0,79039.0,78791.0,78791.0,78086.33333333333,75000.0,74784.66666666667,74466.58333333333,71699.20689655172,69741.0,64598.5,62640.8,61896.0,59303.0,58933.5,56000.0,55330.90909090909,55000.0,54957.0,54536.333333333336,54217.5,53960.666666666664,53304.5,40189.0,37236.0,34302.333333333336,33537.0,32974.0,32136.0,31875.0,30703.333333333332,21987.25,20000.0,18974.5,13036.0,5409.0],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorba ...

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 10: Entry Level Salaries by Position (bar chart)
#
# #### 👇 Tasks
#
# - ✔️ Using `df_salary`, create a horizontal bar chart displaying the salary by position for entry level positions.
# - ✔️ Set an appropriate title.
# - ✔️ Set the height to `800` and do not supply a width (by default, a Plotly figure will expand to fit the window if the `width` parameter is omitted).
# - ✔️ Use the `plotly_white` template.
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
df_salary_entry_level = df_salary[df_salary['experience_level'] == 'EN']

fig = px.bar(
    df_salary_entry_level,
    title='Salary by Position',
    x='avg_salary',
    y='job_title',
    color='avg_salary',
    color_continuous_scale='emrld',
    text='avg_salary',
    template='plotly_white',
    height=800
)
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_yaxes(categoryorder='total ascending')
fig.show()
# YOUR CODE ENDS
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4964bdb1-f08f-46d7-8680-0be105111fc1" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4964bdb1-f08f-46d7-8680-0be105111fc1")) {                    Plotly.newPlot(                        "4964bdb1-f08f-46d7-8680-0be105111fc1",                        [{"alignmentgroup":"True","hovertemplate":"avg_salary=%{marker.color}<br>job_title=%{y}<extra></extra>","legendgroup":"","marker":{"color":[225000.0,110037.0,110000.0,100000.0,100000.0,86996.33333333333,86132.0,79551.0,62640.8,58933.5,55330.90909090909,54536.333333333336,53960.666666666664,32136.0,31875.0,30703.333333333332,21987.25,20000.0,18974.5],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[225000.0,110037.0,110000.0,100000.0,100000.0,86996.33333333333,86132.0,79551.0,62640.8,58933.5,55330.90909090909,54536.333333333336,53960.666666666664,32136.0,31875.0,30703.333333333332,21987.25,20000.0,18974.5],"textposition":"outside","x":[225000.0,110037.0,110000.0,100000.0,100000.0,86996.33333333333,86132.0,79551.0,62640.8,58933.5,55330.90909090909,54536.333333333336,53960.666666666664,32136.0,31875.0,30703.333333333332,21987.25,20000.0,18974.5],"xaxis":"x","y":["Machine Learning Scientist","Applied Data Scientist","Computer Vision Software Engineer","Financial Data Analyst","Machine Learning Developer","Machine Learning Engineer","Research Scientist","Business Data Analyst","Data Science Consultant","Data Engineer","Data Scientist","Computer Vision Engineer","Data Analyst","BI Data Analyst","Applied Machine Learning Scientist","Big Data Engineer","AI Scientist","Data Analytics Engineer","ML Engineer"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colors ...

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 11: Salary Heatmap
#
# #### 👇 Tasks
#
# - ✔️ Draw a heatmap of `avg_salary` in `df_salary`.
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Add an appropriate title to your figure.
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
fig = px.density_heatmap(df_salary, x='avg_salary', y = 'experience_level', text_auto='avg_salary')
fig.show()
# YOUR CODE ENDS
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1d8d54b4-fe00-4104-984a-86bcd14a459a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d8d54b4-fe00-4104-984a-86bcd14a459a")) {                    Plotly.newPlot(                        "1d8d54b4-fe00-4104-984a-86bcd14a459a",                        [{"coloraxis":"coloraxis","hovertemplate":"avg_salary=%{x}<br>experience_level=%{y}<br>count=%{z}<extra></extra>","name":"","texttemplate":"%{z:avg_salary}","x":[600000.0,450000.0,416000.0,405000.0,278500.0,256000.0,245500.0,232500.0,225000.0,201666.66666666666,200000.0,199586.33333333334,195000.0,195000.0,192500.0,187939.4,182076.625,178800.0,170000.0,170000.0,168000.0,166666.66666666666,166040.0,165000.0,160000.0,160000.0,159000.0,158958.33333333334,156738.0,155000.0,152971.0163934426,151419.5,151000.0,150000.0,149994.2,137035.84126984127,137025.0,136498.14285714287,131176.0,127134.28571428571,120000.0,118187.0,117104.0,115285.0,115000.0,111922.62962962964,111535.5,110037.0,110000.0,110000.0,110000.0,109325.0,105619.0,105000.0,103000.0,100000.0,100000.0,99703.0,95746.0,93610.5,89294.0,88859.4,88654.0,87932.0,86996.33333333333,86132.0,85985.6603773585,82039.13333333333,79833.0,79551.0,79039.0,78791.0,78791.0,78086.33333333333,75000.0,74784.66666666667,74466.58333333333,71699.20689655172,69741.0,64598.5,62640.8,61896.0,59303.0,58933.5,56000.0,55330.90909090909,55000.0,54957.0,54536.333333333336,54217.5,53960.666666666664,53304.5,40189.0,37236.0,34302.333333333336,33537.0,32974.0,32136.0,31875.0,30703.333333333332,21987.25,20000.0,18974.5,13036.0,5409.0],"xaxis":"x","xbingroup":"x","y":["EX","MI","EX","SE","SE","SE","EX","EX","EN","SE","MI","EX","SE","SE","SE","SE","SE","MI","SE","SE","SE","MI","SE","SE","SE","MI","SE","EX","SE","EX","SE","SE","MI","EX","SE","SE","MI","MI","SE","SE","EX","EX","SE","SE","MI","SE","SE","EN","MI","MI","EN","MI","MI","SE","MI","EN","EN","SE","MI","SE","MI","SE","SE","SE","EN","EN","MI","MI","EX","EN","EX","SE","MI","MI","MI","MI","MI","MI","EX","SE","EN","SE","MI","EN","MI","EN","SE","MI","EN","MI","EN","MI","MI","MI","SE","MI","MI","EN","EN","EN","EN","EN","EN","MI","MI"],"yaxis":"y","ybingroup":"y","type":"histogram2d"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{ ...

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 12: Salary + Experience Level breakdown (sunburst)
#
# #### 👇 Tasks
#
# - ✔️ Using `df_salary`, create a sunburst chart describing the breakdown of position and experience level.
# - ✔️ Set an appropriate title.
# - ✔️ Set both the width and height to `800`.
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
fig = px.sunburst(
    df_salary,
    path=['experience_level', 'job_title'],
    values='avg_salary',
    title='Salary by Position Breakdown',
    width=800,
    height=800
)
fig.show()
# YOUR CODE ENDS
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cfc4b135-d131-4a49-9204-7393b20cc5ab" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfc4b135-d131-4a49-9204-7393b20cc5ab")) {                    Plotly.newPlot(                        "cfc4b135-d131-4a49-9204-7393b20cc5ab",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>avg_salary=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["MI/3D Computer Vision Researcher","EN/AI Scientist","MI/AI Scientist","SE/AI Scientist","EX/Analytics Engineer","SE/Analytics Engineer","EN/Applied Data Scientist","MI/Applied Data Scientist","SE/Applied Data Scientist","EN/Applied Machine Learning Scientist","MI/Applied Machine Learning Scientist","EN/BI Data Analyst","EX/BI Data Analyst","MI/BI Data Analyst","SE/Big Data Architect","EN/Big Data Engineer","MI/Big Data Engineer","SE/Big Data Engineer","EN/Business Data Analyst","MI/Business Data Analyst","MI/Cloud Data Engineer","SE/Cloud Data Engineer","EN/Computer Vision Engineer","SE/Computer Vision Engineer","EN/Computer Vision Software Engineer","MI/Computer Vision Software Engineer","EN/Data Analyst","EX/Data Analyst","MI/Data Analyst","SE/Data Analyst","EN/Data Analytics Engineer","MI/Data Analytics Engineer","SE/Data Analytics Engineer","SE/Data Analytics Lead","SE/Data Analytics Manager","MI/Data Architect","SE/Data Architect","EN/Data Engineer","EX/Data Engineer","MI/Data Engineer","SE/Data Engineer","EX/Data Engineering Manager","MI/Data Engineering Manager","SE/Data Engineering Manager","EN/Data Science Consultant","EX/Data Science Consultant","MI/Data Science Consultant","MI/Data Science Engineer","SE/Data Science Engineer","MI/Data Science Manager","SE/Data Science Manager","EN/Data Scientist","MI/Data Scientist","SE/Data Scientist","SE/Data Specialist","SE/Director of Data Engineering","EX/Director of Data Science","SE/Director of Data Science","MI/ETL Developer","SE/Finance Data Analyst","EN/Financial Data Analyst","MI/Financial Data Analyst","EX/Head of Data","MI/Head of Data","SE/Head of Data","EX/Head of Data Science","MI/Head of Data Science","EX/Head of Machine Learning","MI/Lead Data Analyst","SE/Lead Data Analyst","EX/Lead Data Engineer","MI/Lead Data Engineer","SE/Lead Data Engineer","MI/Lead Data Scientist","SE/Lead Data Scientist","SE/Lead Machine Learning Engineer","EN/ML Engineer","MI/ML Engineer","SE/ML Engineer","EN/Machine Learning Developer","MI/Machine Learning Developer","SE/Machine Learning Developer","EN/Machine Learning Engineer","MI/Machine Learning Engineer","SE/Machine Learning Engineer","MI/Machine Learning Infrastructure Engineer","SE/Machine Learning Infrastructure Engineer","SE/Machine Learning Manager","EN/Machine Learning Scientist","MI/Machine Learning Scientist","SE/Machine Learning Scientist","SE/Marketing Data Analyst","MI/NLP Engineer","MI/Principal Data Analyst","SE/Principal Data Analyst","EX/Principal Data Engineer","SE/Principal Data Engineer","EX/Principal Data Scientist","MI/Principal Data Scientist","SE/Principal Data Scientist","MI/Product Data Analyst","EN/Research Scientist","MI/Research Scientist","SE/Research Scientist","SE/Staff Data Scientist","EN","EX","MI","SE"],"labels":["3D Computer Vision Researcher","AI Scientist","AI Scientist","AI Scientist","Analytics Engineer","Analytics Engineer","Applied Data Scientist","Applied Data Scientist","Applied Data Scientist","Applied Machine Learning Scientist","Applied Machine Learning Scientist","BI Data Analyst","BI Data Analyst","BI Data Analyst","Big Data Architect","Big Data Engineer","Big Data Engineer","Big Data Engineer","Business Data Analyst","Business Data Analyst","Cloud Data Engineer","Cloud Data Engi ...

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 13: Pickup area breakdown (treemap)
#
# #### 👇 Tasks
#
# - ✔️ Using `df_by_pickup_area`, create a treemap of pickup areas.
# - ✔️ Set an appropriate title.
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
fig = px.treemap(df_entry_level, 
                 path=['job_title'], 
                 values='salary_in_usd', 
                 title='Entry Level Positions Breakdown')
fig.show()
# YOUR CODE ENDS
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="325d6239-399c-4c6f-827f-23bb0241078b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("325d6239-399c-4c6f-827f-23bb0241078b")) {                    Plotly.newPlot(                        "325d6239-399c-4c6f-827f-23bb0241078b",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>salary_in_usd=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["AI Scientist","Applied Data Scientist","Applied Machine Learning Scientist","BI Data Analyst","Big Data Engineer","Business Data Analyst","Computer Vision Engineer","Computer Vision Software Engineer","Data Analyst","Data Analytics Engineer","Data Engineer","Data Science Consultant","Data Scientist","Financial Data Analyst","ML Engineer","Machine Learning Developer","Machine Learning Engineer","Machine Learning Scientist","Research Scientist"],"labels":["AI Scientist","Applied Data Scientist","Applied Machine Learning Scientist","BI Data Analyst","Big Data Engineer","Business Data Analyst","Computer Vision Engineer","Computer Vision Software Engineer","Data Analyst","Data Analytics Engineer","Data Engineer","Data Science Consultant","Data Scientist","Financial Data Analyst","ML Engineer","Machine Learning Developer","Machine Learning Engineer","Machine Learning Scientist","Research Scientist"],"name":"","parents":["","","","","","","","","","","","","","","","","","",""],"values":[87949,110037,31875,64272,92110,159102,163609,220000,647528,20000,707202,313204,1217280,100000,37949,100000,782967,225000,344528],"type":"treemap"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111 ...

# %% [markdown]
# ---
#
# ### 🎯 Deliverable 14: Pickup area breakdown (pie chart)
#
# #### 👇 Tasks
#
# - ✔️ Using `df_by_pickup_area`, create a pie chart of pickup areas.
# - ✔️ Set an appropriate title.
# - ✔️ Store your figure to a variable named `fig`.
# - ✔️ Display the figure using `fig.show()`

# %%
# YOUR CODE BEGINS
fig = px.pie(df_entry_level, 
             values='salary_in_usd', 
             names='job_title', 
             title='Salary of Entry Level Positions')
fig.show()
# YOUR CODE ENDS
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="019ebcf3-1d9c-448a-ac01-74a0a7a62846" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("019ebcf3-1d9c-448a-ac01-74a0a7a62846")) {                    Plotly.newPlot(                        "019ebcf3-1d9c-448a-ac01-74a0a7a62846",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"job_title=%{label}<br>salary_in_usd=%{value}<extra></extra>","labels":["Data Analyst","Data Scientist","Data Scientist","Data Engineer","Data Science Consultant","Research Scientist","Business Data Analyst","Big Data Engineer","Machine Learning Engineer","Data Analyst","Machine Learning Engineer","ML Engineer","Data Analyst","Data Analyst","AI Scientist","Data Engineer","Data Scientist","Data Scientist","Data Scientist","Data Scientist","Research Scientist","Data Analyst","Data Analyst","Data Science Consultant","Data Scientist","AI Scientist","Computer Vision Software Engineer","Data Engineer","AI Scientist","Machine Learning Scientist","Data Analyst","Data Analyst","Applied Data Scientist","Data Analyst","Machine Learning Engineer","Machine Learning Developer","Data Scientist","Data Scientist","Data Scientist","Data Scientist","Machine Learning Engineer","Data Science Consultant","Data Engineer","BI Data Analyst","Data Analyst","Machine Learning Engineer","Machine Learning Engineer","BI Data Analyst","Data Science Consultant","Big Data Engineer","Machine Learning Engineer","Computer Vision Engineer","Big Data Engineer","Data Scientist","Data Engineer","AI Scientist","Data Scientist","Data Scientist","Data Scientist","Data Engineer","Data Engineer","Data Science Consultant","Machine Learning Engineer","Data Scientist","Data Scientist","Business Data Analyst","Research Scientist","Data Engineer","Data Engineer","Machine Learning Engineer","ML Engineer","Computer Vision Engineer","Financial Data Analyst","Data Scientist","Data Engineer","Data Scientist","Applied Machine Learning Scientist","Data Engineer","Data Scientist","Data Scientist","Data Scientist","Research Scientist","Computer Vision Software Engineer","Data Engineer","Data Analytics Engineer","Computer Vision Engineer","Data Analyst","Data Analyst"],"legendgroup":"","name":"","showlegend":true,"values":[72000,51321,39916,41689,5707,42000,100000,70000,250000,10000,138000,15966,6072,91000,45896,54742,21669,62726,49268,105000,82528,80000,59102,76833,29751,12000,70000,30428,12000,225000,90000,50000,110037,10354,20000,100000,49646,100000,80000,13400,125000,63831,80000,55000,60000,81000,21844,9272,90000,5882,24823,28609,16228,4000,21637,18053,36643,90000,28399,65013,72500,76833,85000,100000,58000,59102,100000,52351,45807,37300,21983,125000,100000,18442,120000,100000,31875,58035,52396,40000,86703,120000,150000,65000,20000,10000,67000,52000],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"], ...

# %% [markdown]
# #Part 5: Conclusions
#
# Through analyzing this dataset, I have found some information about the highest paying jobs, locations, and remote/in-office ratios. Some of the most important observations I noticed are listed below:
#
#   1. The highest paying entry level job is ML Engineer, which pays \$250,000 and has a remote ratio of 50\% and is located in the US.
#   2. The highest paying data scientist role is a fully remote senior level role that earns \$412,000 in the US.
#   3. The highest paying job on average, is Principal Data Engineer, which earns \$600,000, based on its occurrences in the dataset.
#   4. The highest paying entry level job on average is ML Scientist.
#   5. In the United States, experts get paid the most on average. In Mexico, the lowest paying experience level is a mid-level engineer.
#   6. All of the top 5 highest paying data scientist job are all fully remote.
#
#
# These were just a few of the conclusions I was able to notice while analyzing this dataset. More specificity can definitely be looked into while analzying larger samples or more columns in this dataset.
